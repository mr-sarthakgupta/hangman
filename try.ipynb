# %%
import numpy as np
import string
import random
import re
import collections
import os
import json
import pickle
import xgboost as xgb

def generate_letter_cofrequency_matrices(words):
        """
        Generate co-frequency matrices for letters that succeed and precede each other.
        
        Parameters:
        words (list): List of words to analyze
        
        Returns:
        tuple: (succeeding_matrix, preceding_matrix)
        """
        # Create lowercase alphabet for matrix indexing
        alphabet = string.ascii_lowercase
        
        # Initialize matrices with zeros
        succeeding_matrix = np.zeros((26, 26), dtype=int)
        preceding_matrix = np.zeros((26, 26), dtype=int)
        
        # Process each word
        for word in words:
            # Convert to lowercase
            word = word.lower()
            
            # Analyze letter successions
            for i in range(len(word) - 1):
                # Current and next letter
                current_letter = word[i]
                next_letter = word[i + 1]
                
                # Skip if either letter is not in alphabet
                if current_letter not in alphabet or next_letter not in alphabet:
                    continue
                
                # Get matrix indices
                current_idx = alphabet.index(current_letter)
                next_idx = alphabet.index(next_letter)
                
                # Increment succeeding matrix
                succeeding_matrix[current_idx, next_idx] += 1
            
            # Analyze letter precedences
            for i in range(1, len(word)):
                # Current and previous letter
                current_letter = word[i]
                prev_letter = word[i - 1]
                
                # Skip if either letter is not in alphabet
                if current_letter not in alphabet or prev_letter not in alphabet:
                    continue
                
                # Get matrix indices
                current_idx = alphabet.index(current_letter)
                prev_idx = alphabet.index(prev_letter)
                
                # Increment preceding matrix
                preceding_matrix[current_idx, prev_idx] += 1
        
        return succeeding_matrix, preceding_matrix


with open("words_train_split.txt", "r") as file:
        words = file.read().splitlines()
        
succeeding_matrix, preceding_matrix = generate_letter_cofrequency_matrices(words)

# %%
from collections import Counter
# Join all the words in the training set into a single string
all_letters = ''.join(words)

# Count the frequency of each letter
letter_counts = Counter(all_letters)

# Sort the letters by frequency in decreasing order
sorted_letters_by_frequency = sorted(letter_counts.items(), key=lambda item: item[1], reverse=True)

# Extract just the letters in sorted order
sorted_letters = [letter for letter, count in sorted_letters_by_frequency]


with open("words_train_split.txt", "r") as file:
    words_split = file.read().splitlines()

# Generate bigrams from the words
bigrams = [word[i:i+2] for word in words_split for i in range(len(word) - 1)]

# Count the frequency of each bigram
bigram_counts = Counter(bigrams)

# Get the 100 most common bigrams
most_common_bigrams = bigram_counts.most_common(len(bigram_counts))

most_common_bigrams = [bigram for bigram, count in most_common_bigrams]



trigrams = [word[i:i+3] for word in words_split for i in range(len(word) - 3)]

# Count the frequency of each bigram
trigram_counts = Counter(trigrams)

# Get the 100 most common bigrams
most_common_trigrams = trigram_counts.most_common(len(trigram_counts))

most_common_trigrams = [trigram for trigram, count in most_common_trigrams]




qgrams = [word[i:i+4] for word in words_split for i in range(len(word) - 4)]

# Count the frequency of each bigram
qgram_counts = Counter(qgrams)

# Get the 100 most common bigrams
most_common_qgrams = qgram_counts.most_common(len(qgram_counts))

most_common_qgrams = [qgram for qgram, count in most_common_qgrams]

# %%
import pickle
import xgboost

class HangmanGame:
    def __init__(self, full_dictionary_location='words_train_split.txt'):

        self.xgboost = pickle.load(open('xgboost_1014319.pkl', "rb"))

        self.guessed_letters = []

        full_dictionary_location = "words_train_split.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)

        val_dictionary_path = 'words_val_split.txt'
        self.val_dictionary = self.build_dictionary(val_dictionary_path)
            
        self.alphabet = string.ascii_lowercase

        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []        

        self.succeeding_matrix, self.preceding_matrix = succeeding_matrix, preceding_matrix

    def guess(self, word, succeeding_matrix, preceding_matrix):
        # Predefined frequency lists
        letters_by_frequency = ['e',
                                'i',
                                'a',
                                'n',
                                'o',
                                'r',
                                's',
                                't',
                                'l',
                                'c',
                                'u',
                                'd',
                                'p',
                                'm',
                                'h',
                                'g',
                                'y',
                                'b',
                                'f',
                                'v',
                                'k',
                                'w',
                                'z',
                                'x',
                                'q',
                                'j']
        letters_by_frequency = letters_by_frequency[::-1]

        bigrams_by_frequency = most_common_bigrams
        bigrams_by_frequency = bigrams_by_frequency[::-1] 


        trigrams_by_frequency = most_common_trigrams
        trigrams_by_frequency = trigrams_by_frequency[::-1]


        quadgrams_by_frequency = most_common_qgrams        
        quadgrams_by_frequency = quadgrams_by_frequency[::-1]


        # Clean the word, stripping spaces and replacing "_" with placeholders
        clean_word = word[::2].replace("_", ".")
    
        # Score mechanism for letter selection
        letter_scores = {}
        
        # 1. Single Letter Frequency - Initial Base Score
        for letter in letters_by_frequency:
            if letter not in self.guessed_letters:
                letter_scores[letter] = [0]*6

        for letter in letters_by_frequency:
            if letter not in self.guessed_letters:
                letter_scores[letter][0] += 26*26*26*letters_by_frequency.index(letter) + 1

        # 2. Bigram and  Scoring with Contextual Constraint
        for i in range(len(clean_word) - 1):
            # Extract 2-letter window
            window = clean_word[i:i+2]
            
            # Count known letters in the window
            known_letters_count = sum(1 for char in window if char != '.')
            
            # Only apply bigram scoring if 1 or more letters are known
            if known_letters_count == 1:
                for bigram in bigrams_by_frequency:
                    if self.is_bigram_window_match(window, bigram):
                        for letter in set(bigram):
                            if letter not in self.guessed_letters and letter not in window:
                                letter_scores[letter][1] += 26*26*bigrams_by_frequency.index(bigram) + 1
                                        
        
        # 3. Trigram Scoring with Contextual Constraint
        for i in range(len(clean_word) - 2):
            # Extract 3-letter window
            window = clean_word[i:i+3]
            
            # Count known letters in the window
            known_letters_count = sum(1 for char in window if char != '.')
            
            # Only apply trigram scoring if 2 or more letters are known
            if known_letters_count >= 2:
                for trigram in trigrams_by_frequency:
                    if self.is_trigram_window_match(window, trigram):
                        for letter in set(trigram):
                            if letter not in self.guessed_letters and letter not in window:
                                letter_scores[letter][2] += 26*trigrams_by_frequency.index(trigram) + 1
    
        # 4. Quadgram Scoring with Contextual Constraint
        for i in range(len(clean_word) - 3):
            # Extract 4-letter window
            window = clean_word[i:i+4]
            
            # Count known letters in the window
            known_letters_count = sum(1 for char in window if char != '.')
            
            # Only apply quadgram scoring if 2 or more letters are known
            if known_letters_count >= 3:
                for quadgram in quadgrams_by_frequency:
                    if self.is_quadgram_window_match(window, quadgram):
                        for letter in set(quadgram):
                            if letter not in self.guessed_letters and letter not in window:
                                letter_scores[letter][3] += quadgrams_by_frequency.index(quadgram) + 1

        
        # Fallback to most frequent unguessed letters
        if not letter_scores:
            for letter in letters_by_frequency:
                if letter not in self.guessed_letters:
                    return letter

        input = np.array([sum(letter_scores[letter]) if letter in letter_scores.keys() else -1000*7 for letter in string.ascii_lowercase])

        output_file_path = f'embeddings/{word.replace(".", "_")} ~ {self.secret_word}.txt'
        with open(output_file_path, 'w') as f:
            for letter, scores in letter_scores.items():
                f.write(f"{letter}: {scores}\n")
        
        

        guess_letter = string.ascii_lowercase[np.argmax(input)]

        # if clean_word == '.'*len(clean_word) and 'e' not in self.guessed_letters:
        #     guess_letter = 'e'
        # else:
        #     output = self.predict_multilabel(models = self.xgboost, X_test = np.expand_dims(input, axis=0), n_classes = n_classes, threshold=0.5).squeeze().argsort()
        #     output = output[::-1]
        #     # guess_letter = string.ascii_lowercase[output[i]]
        #     for i in range(26):
        #         if string.ascii_lowercase[output[i]] not in self.guessed_letters:
        #             guess_letter = string.ascii_lowercase[output[i]]
        #             break

        # print(f"Guessed letter: {guess_letter}, rank: {i + 1}, score: {sum(letter_scores[guess_letter])}")
            
        return guess_letter
    
    def predict_multilabel(self, models, X_test, n_classes, threshold=0.5):
        # Predict probabilities for each label
        preds_proba = np.column_stack([
            model.predict(xgb.DMatrix(X_test)) for model in models
        ])
        
        # Convert probabilities to binary predictions
        preds_bin = (preds_proba >= threshold).astype(int)
        
        return preds_bin
    
    def is_bigram_window_match(self, window, bigram):
        """
        Check if a bigram is compatible with a 2-letter word window
        
        Example matches:
        '_ e' matches 'he'
        'h _' matches 'hi'
        """
        # Convert window to regex pattern, replacing dots with wildcards
        pattern = '^' + ''.join([c if c != '.' else '[a-z]' for c in window]) + '$'
        
        return re.match(pattern, bigram, re.IGNORECASE) is not None

    def is_trigram_window_match(self, window, trigram):
        """
        Check if a trigram is compatible with a 3-letter word window
        
        Example matches:
        '_ _ e' matches 'the'
        'h e _' matches 'her'
        """
        # Convert window to regex pattern, replacing dots with wildcards
        pattern = '^' + ''.join([c if c != '.' else '[a-z]' for c in window]) + '$'
        
        return re.match(pattern, trigram, re.IGNORECASE) is not None

    def is_quadgram_window_match(self, window, quadgram):
        """
        Check if a quadgram is compatible with a 4-letter word window
        
        Example matches:
        '_ _ e r' matches 'ther'
        'w i t _' matches 'with'
        """
        # Convert window to regex pattern, replacing dots with wildcards
        pattern = '^' + ''.join([c if c != '.' else '[a-z]' for c in window]) + '$'

        return re.match(pattern, quadgram, re.IGNORECASE) is not None

    def is_ngram_compatible(self, ngram, word_pattern):
        """
        Check if an ngram is compatible with the current word pattern
        """
        # Create a regex pattern from the ngram that respects the word pattern
        pattern = word_pattern.replace('.', '[a-z]')
        
        # Check if the ngram could exist within the pattern
        return re.search(f'(?=.{ngram}.)', pattern, re.IGNORECASE) is not None
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
        
    def start_game(self, secret_word=None, verbose=True):
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
        if secret_word is None:
            secret_word = random.choice(self.val_dictionary)
        self.secret_word = secret_word
        word = ' '.join(['_' for _ in secret_word])
        tries_remains = 6
        if verbose:
            print("Successfully start a new game! # of tries remaining: {0}. Word: {1}.".format(tries_remains, word))
        while tries_remains > 0:
            # get guessed letter from user code
            guess_letter = self.guess(word, self.succeeding_matrix, self.preceding_matrix)
            
            # append guessed letter to guessed letters field in hangman object
            self.guessed_letters.append(guess_letter)
            if verbose:
                print("Guessing letter: {0}".format(guess_letter))

            if guess_letter in secret_word:
                # update word with guessed letter
                word = ' '.join([letter if letter == guess_letter else word[index*2] for index, letter in enumerate(secret_word)])
            if guess_letter not in secret_word:
                tries_remains -= 1

            if tries_remains > 0:
                status = 'ongoing'
            if '_' not in word:
                status = 'success'            
            if tries_remains == 0:
                status = 'failed'
            res = {'status': status, 'tries_remains': tries_remains, 'word': word, 'secret_word': secret_word, 'guessed_letters': self.guessed_letters}  
            if verbose:
                print(res)

            if status == 'success':
                print("Successfully finished game, the word was: {0}!".format(secret_word))
                return True

            if status == 'failed':
                print("Failed game because of: # of tries exceeded!")
                return False
            
        return status=="success"
    
game = HangmanGame()
game.start_game(secret_word='welder')
# Out:
# Successfully start a new game! # of tries remaining: 6. Word: _ _ _ _ _ _.
# Guessing letter: e
# {'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _', 'secret_word': 'welder', 'guessed_letters': ['e']}
# Guessing letter: n
# {'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _', 'secret_word': 'welder', 'guessed_letters': ['e', 'n']}
# Guessing letter: r
# {'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r']}
# Guessing letter: s
# {'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r', 's']}
# Guessing letter: t
# {'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r', 's', 't']}
# Guessing letter: l
# {'status': 'ongoing', 'tries_remains': 3, 'word': '_ e l _ e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r', 's', 't', 'l']}
# Guessing letter: i
# {'status': 'ongoing', 'tries_remains': 2, 'word': '_ e l _ e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r', 's', 't', 'l', 'i']}
# Guessing letter: d
# {'status': 'ongoing', 'tries_remains': 2, 'word': '_ e l d e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r', 's', 't', 'l', 'i', 'd']}
# Guessing letter: c
# {'status': 'ongoing', 'tries_remains': 1, 'word': '_ e l d e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r', 's', 't', 'l', 'i', 'd', 'c']}
# Guessing letter: a
# {'status': 'failed', 'tries_remains': 0, 'word': '_ e l d e r', 'secret_word': 'welder', 'guessed_letters': ['e', 'n', 'r', 's', 't', 'l', 'i', 'd', 'c', 'a']}
# Failed game because of: # of tries exceeded!
# False

# %%
with open("words_train_split.txt", "r") as file:
        words = file.read().splitlines()

num_success = 0

for i, word in enumerate(words):
    print(i)
    if i == 500:
        break
    game = HangmanGame()
    s = game.start_game(secret_word=word, verbose=False)
    if s:
        num_success += 1
# Out:
# 0
# Failed game because of: # of tries exceeded!
# 1
# Failed game because of: # of tries exceeded!
# 2
# Failed game because of: # of tries exceeded!
# 3
# Successfully finished game, the word was: nonecstatic!
# 4
# Successfully finished game, the word was: obtusangular!
# 5
# Failed game because of: # of tries exceeded!
# 6
# Successfully finished game, the word was: medicated!
# 7
# Failed game because of: # of tries exceeded!
# 8
# Successfully finished game, the word was: schlesien!
# 9
# Successfully finished game, the word was: egalitarian!
# 10
# Failed game because of: # of tries exceeded!
# 11
# Failed game because of: # of tries exceeded!
# 12
# Failed game because of: # of tries exceeded!
# 13
# Successfully finished game, the word was: unsanctionable!
# 14
# Failed game because of: # of tries exceeded!
# 15
# Failed game because of: # of tries exceeded!
# 16
# Failed game because of: # of tries exceeded!
# 17
# Successfully finished game, the word was: culminative!
# 18
# Failed game because of: # of tries exceeded!
# 19
# Successfully finished game, the word was: unstatistic!
# 20
# Failed game because of: # of tries exceeded!
# 21
# Failed game because of: # of tries exceeded!
# 22
# Failed game because of: # of tries exceeded!
# 23
# Failed game because of: # of tries exceeded!
# 24
# Failed game because of: # of tries exceeded!
# 25
# Failed game because of: # of tries exceeded!
# 26
# Failed game because of: # of tries exceeded!
# 27
# Failed game because of: # of tries exceeded!
# 28
# Successfully finished game, the word was: phlogistication!
# 29
# Failed game because of: # of tries exceeded!
# 30
# Failed game because of: # of tries exceeded!
# 31
# Successfully finished game, the word was: daisied!
# 32
# Failed game because of: # of tries exceeded!
# 33
# Successfully finished game, the word was: trackless!
# 34
# Successfully finished game, the word was: nematocidal!
# 35
# Failed game because of: # of tries exceeded!
# 36
# Failed game because of: # of tries exceeded!
# 37
# Failed game because of: # of tries exceeded!
# 38
# Successfully finished game, the word was: arditi!
# 39
# Successfully finished game, the word was: precirculate!
# 40
# Failed game because of: # of tries exceeded!
# 41
# Failed game because of: # of tries exceeded!
# 42
# Failed game because of: # of tries exceeded!
# 43
# Failed game because of: # of tries exceeded!
# 44
# Successfully finished game, the word was: coronels!
# 45
# Failed game because of: # of tries exceeded!
# 46
# Failed game because of: # of tries exceeded!
# 47
# Failed game because of: # of tries exceeded!
# 48
# Successfully finished game, the word was: pentafluoride!
# 49
# Failed game because of: # of tries exceeded!
# 50
# Failed game because of: # of tries exceeded!
# 51
# Failed game because of: # of tries exceeded!
# 52
# Failed game because of: # of tries exceeded!
# 53
# Failed game because of: # of tries exceeded!
# 54
# Failed game because of: # of tries exceeded!
# 55
# Failed game because of: # of tries exceeded!
# 56
# Failed game because of: # of tries exceeded!
# 57
# Successfully finished game, the word was: ornithomimid!
# 58
# Failed game because of: # of tries exceeded!
# 59
# Failed game because of: # of tries exceeded!
# 60
# Failed game because of: # of tries exceeded!
# 61
# Failed game because of: # of tries exceeded!
# 62
# Failed game because of: # of tries exceeded!
# 63
# Failed game because of: # of tries exceeded!
# 64
# Failed game because of: # of tries exceeded!
# 65
# Failed game because of: # of tries exceeded!
# 66
# Failed game because of: # of tries exceeded!
# 67
# Successfully finished game, the word was: reunited!
# 68
# Failed game because of: # of tries exceeded!
# 69
# Successfully finished game, the word was: ain!
# 70
# Failed game because of: # of tries exceeded!
# 71
# Failed game because of: # of tries exceeded!
# 72
# Failed game because of: # of tries exceeded!
# 73
# Failed game because of: # of tries exceeded!
# 74
# Failed game because of: # of tries exceeded!
# 75
# Successfully finished game, the word was: leposternon!
# 76
# Successfully finished game, the word was: northering!
# 77
# Failed game because of: # of tries exceeded!
# 78
# Failed game because of: # of tries exceeded!
# 79
# Failed game because of: # of tries exceeded!
# 80
# Failed game because of: # of tries exceeded!
# 81
# Successfully finished game, the word was: arsis!
# 82
# Successfully finished game, the word was: designers!
# 83
# Failed game because of: # of tries exceeded!
# 84
# Failed game because of: # of tries exceeded!
# 85
# Failed game because of: # of tries exceeded!
# 86
# Failed game because of: # of tries exceeded!
# 87
# Failed game because of: # of tries exceeded!
# 88
# Successfully finished game, the word was: cutaiar!
# 89
# Failed game because of: # of tries exceeded!
# 90
# Successfully finished game, the word was: classmanship!
# 91
# Successfully finished game, the word was: socialising!
# 92
# Failed game because of: # of tries exceeded!
# 93
# Successfully finished game, the word was: allophones!
# 94
# Failed game because of: # of tries exceeded!
# 95
# Successfully finished game, the word was: theridion!
# 96
# Failed game because of: # of tries exceeded!
# 97
# Failed game because of: # of tries exceeded!
# 98
# Failed game because of: # of tries exceeded!
# 99
# Successfully finished game, the word was: scorpaena!
# 100
# Failed game because of: # of tries exceeded!
# 101
# Successfully finished game, the word was: ilioperoneal!
# 102
# Successfully finished game, the word was: underpresence!
# 103
# Failed game because of: # of tries exceeded!
# 104
# Successfully finished game, the word was: parcelmad!
# 105
# Successfully finished game, the word was: cristabel!
# 106
# Failed game because of: # of tries exceeded!
# 107
# Successfully finished game, the word was: adumbrations!
# 108
# Failed game because of: # of tries exceeded!
# 109
# Failed game because of: # of tries exceeded!
# 110
# Failed game because of: # of tries exceeded!
# 111
# Failed game because of: # of tries exceeded!
# 112
# Failed game because of: # of tries exceeded!
# 113
# Failed game because of: # of tries exceeded!
# 114
# Failed game because of: # of tries exceeded!
# 115
# Failed game because of: # of tries exceeded!
# 116
# Failed game because of: # of tries exceeded!
# 117
# Failed game because of: # of tries exceeded!
# 118
# Failed game because of: # of tries exceeded!
# 119
# Failed game because of: # of tries exceeded!
# 120
# Failed game because of: # of tries exceeded!
# 121
# Successfully finished game, the word was: crescendi!
# 122
# Failed game because of: # of tries exceeded!
# 123
# Failed game because of: # of tries exceeded!
# 124
# Successfully finished game, the word was: carpopedal!
# 125
# Successfully finished game, the word was: talers!
# 126
# Failed game because of: # of tries exceeded!
# 127
# Failed game because of: # of tries exceeded!
# 128
# Failed game because of: # of tries exceeded!
# 129
# Failed game because of: # of tries exceeded!
# 130
# Successfully finished game, the word was: chelicerate!
# 131
# Failed game because of: # of tries exceeded!
# 132
# Successfully finished game, the word was: echinodermata!
# 133
# Successfully finished game, the word was: subcontract!
# 134
# Failed game because of: # of tries exceeded!
# 135
# Failed game because of: # of tries exceeded!
# 136
# Failed game because of: # of tries exceeded!
# 137
# Failed game because of: # of tries exceeded!
# 138
# Successfully finished game, the word was: harleton!
# 139
# Failed game because of: # of tries exceeded!
# 140
# Failed game because of: # of tries exceeded!
# 141
# Successfully finished game, the word was: underteamed!
# 142
# Successfully finished game, the word was: escocheon!
# 143
# Failed game because of: # of tries exceeded!
# 144
# Failed game because of: # of tries exceeded!
# 145
# Failed game because of: # of tries exceeded!
# 146
# Failed game because of: # of tries exceeded!
# 147
# Failed game because of: # of tries exceeded!
# 148
# Failed game because of: # of tries exceeded!
# 149
# Failed game because of: # of tries exceeded!
# 150
# Failed game because of: # of tries exceeded!
# 151
# Failed game because of: # of tries exceeded!
# 152
# Failed game because of: # of tries exceeded!
# 153
# Failed game because of: # of tries exceeded!
# 154
# Failed game because of: # of tries exceeded!
# 155
# Successfully finished game, the word was: undersea!
# 156
# Failed game because of: # of tries exceeded!
# 157
# Successfully finished game, the word was: startles!
# 158
# Failed game because of: # of tries exceeded!
# 159
# Failed game because of: # of tries exceeded!
# 160
# Failed game because of: # of tries exceeded!
# 161
# Failed game because of: # of tries exceeded!
# 162
# Successfully finished game, the word was: reilluminate!
# 163
# Failed game because of: # of tries exceeded!
# 164
# Failed game because of: # of tries exceeded!
# 165
# Failed game because of: # of tries exceeded!
# 166
# Failed game because of: # of tries exceeded!
# 167
# Successfully finished game, the word was: interpellation!
# 168
# Failed game because of: # of tries exceeded!
# 169
# Failed game because of: # of tries exceeded!
# 170
# Failed game because of: # of tries exceeded!
# 171
# Failed game because of: # of tries exceeded!
# 172
# Failed game because of: # of tries exceeded!
# 173
# Failed game because of: # of tries exceeded!
# 174
# Failed game because of: # of tries exceeded!
# 175
# Successfully finished game, the word was: strengthrestoring!
# 176
# Failed game because of: # of tries exceeded!
# 177
# Failed game because of: # of tries exceeded!
# 178
# Failed game because of: # of tries exceeded!
# 179
# Successfully finished game, the word was: monosymmetric!
# 180
# Failed game because of: # of tries exceeded!
# 181
# Failed game because of: # of tries exceeded!
# 182
# Failed game because of: # of tries exceeded!
# 183
# Successfully finished game, the word was: immetrically!
# 184
# Failed game because of: # of tries exceeded!
# 185
# Failed game because of: # of tries exceeded!
# 186
# Successfully finished game, the word was: nonincandescent!
# 187
# Failed game because of: # of tries exceeded!
# 188
# Successfully finished game, the word was: subcultured!
# 189
# Failed game because of: # of tries exceeded!
# 190
# Failed game because of: # of tries exceeded!
# 191
# Successfully finished game, the word was: acestoma!
# 192
# Failed game because of: # of tries exceeded!
# 193
# Successfully finished game, the word was: oldgentlemanly!
# 194
# Failed game because of: # of tries exceeded!
# 195
# Failed game because of: # of tries exceeded!
# 196
# Failed game because of: # of tries exceeded!
# 197
# Failed game because of: # of tries exceeded!
# 198
# Failed game because of: # of tries exceeded!
# 199
# Successfully finished game, the word was: eliasite!
# 200
# Failed game because of: # of tries exceeded!
# 201
# Failed game because of: # of tries exceeded!
# 202
# Failed game because of: # of tries exceeded!
# 203
# Successfully finished game, the word was: undextrousness!
# 204
# Failed game because of: # of tries exceeded!
# 205
# Successfully finished game, the word was: coates!
# 206
# Failed game because of: # of tries exceeded!
# 207
# Successfully finished game, the word was: dysepulotical!
# 208
# Successfully finished game, the word was: solideo!
# 209
# Failed game because of: # of tries exceeded!
# 210
# Failed game because of: # of tries exceeded!
# 211
# Failed game because of: # of tries exceeded!
# 212
# Failed game because of: # of tries exceeded!
# 213
# Failed game because of: # of tries exceeded!
# 214
# Failed game because of: # of tries exceeded!
# 215
# Failed game because of: # of tries exceeded!
# 216
# Successfully finished game, the word was: indenting!
# 217
# Failed game because of: # of tries exceeded!
# 218
# Failed game because of: # of tries exceeded!
# 219
# Failed game because of: # of tries exceeded!
# 220
# Successfully finished game, the word was: grosgrained!
# 221
# Failed game because of: # of tries exceeded!
# 222
# Failed game because of: # of tries exceeded!
# 223
# Successfully finished game, the word was: liltingness!
# 224
# Successfully finished game, the word was: ethnomusicologist!
# 225
# Failed game because of: # of tries exceeded!
# 226
# Failed game because of: # of tries exceeded!
# 227
# Failed game because of: # of tries exceeded!
# 228
# Failed game because of: # of tries exceeded!
# 229
# Failed game because of: # of tries exceeded!
# 230
# Successfully finished game, the word was: unstoutly!
# 231
# Failed game because of: # of tries exceeded!
# 232
# Failed game because of: # of tries exceeded!
# 233
# Failed game because of: # of tries exceeded!
# 234
# Failed game because of: # of tries exceeded!
# 235
# Failed game because of: # of tries exceeded!
# 236
# Failed game because of: # of tries exceeded!
# 237
# Failed game because of: # of tries exceeded!
# 238
# Failed game because of: # of tries exceeded!
# 239
# Successfully finished game, the word was: theanthropist!
# 240
# Failed game because of: # of tries exceeded!
# 241
# Failed game because of: # of tries exceeded!
# 242
# Failed game because of: # of tries exceeded!
# 243
# Failed game because of: # of tries exceeded!
# 244
# Failed game because of: # of tries exceeded!
# 245
# Failed game because of: # of tries exceeded!
# 246
# Successfully finished game, the word was: hemapophysis!
# 247
# Failed game because of: # of tries exceeded!
# 248
# Failed game because of: # of tries exceeded!
# 249
# Failed game because of: # of tries exceeded!
# 250
# Failed game because of: # of tries exceeded!
# 251
# Failed game because of: # of tries exceeded!
# 252
# Failed game because of: # of tries exceeded!
# 253
# Successfully finished game, the word was: nonconfidently!
# 254
# Failed game because of: # of tries exceeded!
# 255
# Failed game because of: # of tries exceeded!
# 256
# Successfully finished game, the word was: synchroneity!
# 257
# Failed game because of: # of tries exceeded!
# 258
# Failed game because of: # of tries exceeded!
# 259
# Failed game because of: # of tries exceeded!
# 260
# Failed game because of: # of tries exceeded!
# 261
# Failed game because of: # of tries exceeded!
# 262
# Failed game because of: # of tries exceeded!
# 263
# Failed game because of: # of tries exceeded!
# 264
# Failed game because of: # of tries exceeded!
# 265
# Successfully finished game, the word was: melanic!
# 266
# Successfully finished game, the word was: lithotome!
# 267
# Failed game because of: # of tries exceeded!
# 268
# Failed game because of: # of tries exceeded!
# 269
# Failed game because of: # of tries exceeded!
# 270
# Failed game because of: # of tries exceeded!
# 271
# Failed game because of: # of tries exceeded!
# 272
# Failed game because of: # of tries exceeded!
# 273
# Failed game because of: # of tries exceeded!
# 274
# Failed game because of: # of tries exceeded!
# 275
# Failed game because of: # of tries exceeded!
# 276
# Failed game because of: # of tries exceeded!
# 277
# Failed game because of: # of tries exceeded!
# 278
# Failed game because of: # of tries exceeded!
# 279
# Failed game because of: # of tries exceeded!
# 280
# Failed game because of: # of tries exceeded!
# 281
# Failed game because of: # of tries exceeded!
# 282
# Successfully finished game, the word was: uncleanliness!
# 283
# Failed game because of: # of tries exceeded!
# 284
# Failed game because of: # of tries exceeded!
# 285
# Failed game because of: # of tries exceeded!
# 286
# Failed game because of: # of tries exceeded!
# 287
# Failed game because of: # of tries exceeded!
# 288
# Failed game because of: # of tries exceeded!
# 289
# Failed game because of: # of tries exceeded!
# 290
# Failed game because of: # of tries exceeded!
# 291
# Failed game because of: # of tries exceeded!
# 292
# Successfully finished game, the word was: ressler!
# 293
# Successfully finished game, the word was: chashitsu!
# 294
# Failed game because of: # of tries exceeded!
# 295
# Failed game because of: # of tries exceeded!
# 296
# Successfully finished game, the word was: splenoblast!
# 297
# Failed game because of: # of tries exceeded!
# 298
# Successfully finished game, the word was: crustification!
# 299
# Successfully finished game, the word was: microsporidia!
# 300
# Failed game because of: # of tries exceeded!
# 301
# Failed game because of: # of tries exceeded!
# 302
# Successfully finished game, the word was: southerners!
# 303
# Failed game because of: # of tries exceeded!
# 304
# Failed game because of: # of tries exceeded!
# 305
# Successfully finished game, the word was: overmedicating!
# 306
# Failed game because of: # of tries exceeded!
# 307
# Failed game because of: # of tries exceeded!
# 308
# Failed game because of: # of tries exceeded!
# 309
# Failed game because of: # of tries exceeded!
# 310
# Failed game because of: # of tries exceeded!
# 311
# Successfully finished game, the word was: ethene!
# 312
# Failed game because of: # of tries exceeded!
# 313
# Failed game because of: # of tries exceeded!
# 314
# Successfully finished game, the word was: scraiched!
# 315
# Failed game because of: # of tries exceeded!
# 316
# Failed game because of: # of tries exceeded!
# 317
# Successfully finished game, the word was: macrodactylous!
# 318
# Successfully finished game, the word was: semimonarchically!
# 319
# Failed game because of: # of tries exceeded!
# 320
# Failed game because of: # of tries exceeded!
# 321
# Successfully finished game, the word was: noctor!
# 322
# Failed game because of: # of tries exceeded!
# 323
# Failed game because of: # of tries exceeded!
# 324
# Failed game because of: # of tries exceeded!
# 325
# Successfully finished game, the word was: lipochondroma!
# 326
# Successfully finished game, the word was: staminode!
# 327
# Failed game because of: # of tries exceeded!
# 328
# Successfully finished game, the word was: perhydrogenation!
# 329
# Successfully finished game, the word was: curbable!
# 330
# Failed game because of: # of tries exceeded!
# 331
# Successfully finished game, the word was: unremittently!
# 332
# Failed game because of: # of tries exceeded!
# 333
# Failed game because of: # of tries exceeded!
# 334
# Successfully finished game, the word was: tendrilous!
# 335
# Failed game because of: # of tries exceeded!
# 336
# Failed game because of: # of tries exceeded!
# 337
# Failed game because of: # of tries exceeded!
# 338
# Failed game because of: # of tries exceeded!
# 339
# Successfully finished game, the word was: nutrilite!
# 340
# Successfully finished game, the word was: aet!
# 341
# Failed game because of: # of tries exceeded!
# 342
# Successfully finished game, the word was: talismans!
# 343
# Failed game because of: # of tries exceeded!
# 344
# Failed game because of: # of tries exceeded!
# 345
# Failed game because of: # of tries exceeded!
# 346
# Failed game because of: # of tries exceeded!
# 347
# Successfully finished game, the word was: transparish!
# 348
# Failed game because of: # of tries exceeded!
# 349
# Failed game because of: # of tries exceeded!
# 350
# Failed game because of: # of tries exceeded!
# 351
# Failed game because of: # of tries exceeded!
# 352
# Failed game because of: # of tries exceeded!
# 353
# Failed game because of: # of tries exceeded!
# 354
# Successfully finished game, the word was: tartronate!
# 355
# Failed game because of: # of tries exceeded!
# 356
# Failed game because of: # of tries exceeded!
# 357
# Failed game because of: # of tries exceeded!
# 358
# Failed game because of: # of tries exceeded!
# 359
# Successfully finished game, the word was: synthesist!
# 360
# Successfully finished game, the word was: additionally!
# 361
# Successfully finished game, the word was: incant!
# 362
# Failed game because of: # of tries exceeded!
# 363
# Failed game because of: # of tries exceeded!
# 364
# Successfully finished game, the word was: unshackle!
# 365
# Failed game because of: # of tries exceeded!
# 366
# Failed game because of: # of tries exceeded!
# 367
# Failed game because of: # of tries exceeded!
# 368
# Failed game because of: # of tries exceeded!
# 369
# Failed game because of: # of tries exceeded!
# 370
# Successfully finished game, the word was: esperantic!
# 371
# Successfully finished game, the word was: recolonise!
# 372
# Successfully finished game, the word was: sparelooking!
# 373
# Successfully finished game, the word was: colusa!
# 374
# Successfully finished game, the word was: patcheries!
# 375
# Successfully finished game, the word was: epipsychidion!
# 376
# Successfully finished game, the word was: laitance!
# 377
# Successfully finished game, the word was: conterminal!
# 378
# Failed game because of: # of tries exceeded!
# 379
# Successfully finished game, the word was: laicise!
# 380
# Failed game because of: # of tries exceeded!
# 381
# Failed game because of: # of tries exceeded!
# 382
# Failed game because of: # of tries exceeded!
# 383
# Successfully finished game, the word was: slae!
# 384
# Failed game because of: # of tries exceeded!
# 385
# Failed game because of: # of tries exceeded!
# 386
# Failed game because of: # of tries exceeded!
# 387
# Successfully finished game, the word was: espinette!
# 388
# Failed game because of: # of tries exceeded!
# 389
# Failed game because of: # of tries exceeded!
# 390
# Failed game because of: # of tries exceeded!
# 391
# Failed game because of: # of tries exceeded!
# 392
# Failed game because of: # of tries exceeded!
# 393
# Failed game because of: # of tries exceeded!
# 394
# Successfully finished game, the word was: endobronchitis!
# 395
# Failed game because of: # of tries exceeded!
# 396
# Failed game because of: # of tries exceeded!
# 397
# Failed game because of: # of tries exceeded!
# 398
# Failed game because of: # of tries exceeded!
# 399
# Successfully finished game, the word was: ungenius!
# 400
# Failed game because of: # of tries exceeded!
# 401
# Failed game because of: # of tries exceeded!
# 402
# Failed game because of: # of tries exceeded!
# 403
# Failed game because of: # of tries exceeded!
# 404
# Failed game because of: # of tries exceeded!
# 405
# Successfully finished game, the word was: outers!
# 406
# Failed game because of: # of tries exceeded!
# 407
# Failed game because of: # of tries exceeded!
# 408
# Failed game because of: # of tries exceeded!
# 409
# Failed game because of: # of tries exceeded!
# 410
# Failed game because of: # of tries exceeded!
# 411
# Failed game because of: # of tries exceeded!
# 412
# Successfully finished game, the word was: triphysite!
# 413
# Failed game because of: # of tries exceeded!
# 414
# Successfully finished game, the word was: eproboscidea!
# 415
# Successfully finished game, the word was: orchardmen!
# 416
# Failed game because of: # of tries exceeded!
# 417
# Failed game because of: # of tries exceeded!
# 418
# Failed game because of: # of tries exceeded!
# 419
# Failed game because of: # of tries exceeded!
# 420
# Failed game because of: # of tries exceeded!
# 421
# Failed game because of: # of tries exceeded!
# 422
# Failed game because of: # of tries exceeded!
# 423
# Failed game because of: # of tries exceeded!
# 424
# Failed game because of: # of tries exceeded!
# 425
# Failed game because of: # of tries exceeded!
# 426
# Failed game because of: # of tries exceeded!
# 427
# Failed game because of: # of tries exceeded!
# 428
# Failed game because of: # of tries exceeded!
# 429
# Successfully finished game, the word was: acrimonious!
# 430
# Failed game because of: # of tries exceeded!
# 431
# Failed game because of: # of tries exceeded!
# 432
# Successfully finished game, the word was: synchrony!
# 433
# Failed game because of: # of tries exceeded!
# 434
# Successfully finished game, the word was: distemperature!
# 435
# Failed game because of: # of tries exceeded!
# 436
# Failed game because of: # of tries exceeded!
# 437
# Failed game because of: # of tries exceeded!
# 438
# Successfully finished game, the word was: talliers!
# 439
# Failed game because of: # of tries exceeded!
# 440
# Failed game because of: # of tries exceeded!
# 441
# Failed game because of: # of tries exceeded!
# 442
# Failed game because of: # of tries exceeded!
# 443
# Failed game because of: # of tries exceeded!
# 444
# Failed game because of: # of tries exceeded!
# 445
# Failed game because of: # of tries exceeded!
# 446
# Successfully finished game, the word was: protestors!
# 447
# Failed game because of: # of tries exceeded!
# 448
# Failed game because of: # of tries exceeded!
# 449
# Failed game because of: # of tries exceeded!
# 450
# Failed game because of: # of tries exceeded!
# 451
# Failed game because of: # of tries exceeded!
# 452
# Failed game because of: # of tries exceeded!
# 453
# Failed game because of: # of tries exceeded!
# 454
# Failed game because of: # of tries exceeded!
# 455
# Failed game because of: # of tries exceeded!
# 456
# Successfully finished game, the word was: serpulidan!
# 457
# Successfully finished game, the word was: stachydrine!
# 458
# Failed game because of: # of tries exceeded!
# 459
# Failed game because of: # of tries exceeded!
# 460
# Failed game because of: # of tries exceeded!
# 461
# Failed game because of: # of tries exceeded!
# 462
# Failed game because of: # of tries exceeded!
# 463
# Successfully finished game, the word was: aithochroi!
# 464
# Failed game because of: # of tries exceeded!
# 465
# Failed game because of: # of tries exceeded!
# 466
# Successfully finished game, the word was: appreciational!
# 467
# Failed game because of: # of tries exceeded!
# 468
# Failed game because of: # of tries exceeded!
# 469
# Successfully finished game, the word was: seecatchie!
# 470
# Failed game because of: # of tries exceeded!
# 471
# Successfully finished game, the word was: unillumination!
# 472
# Failed game because of: # of tries exceeded!
# 473
# Failed game because of: # of tries exceeded!
# 474
# Successfully finished game, the word was: surliness!
# 475
# Successfully finished game, the word was: seeland!
# 476
# Successfully finished game, the word was: asante!
# 477
# Failed game because of: # of tries exceeded!
# 478
# Failed game because of: # of tries exceeded!
# 479
# Failed game because of: # of tries exceeded!
# 480
# Successfully finished game, the word was: scutated!
# 481
# Failed game because of: # of tries exceeded!
# 482
# Successfully finished game, the word was: totalitarians!
# 483
# Successfully finished game, the word was: caecilian!
# 484
# Failed game because of: # of tries exceeded!
# 485
# Failed game because of: # of tries exceeded!
# 486
# Failed game because of: # of tries exceeded!
# 487
# Successfully finished game, the word was: holostei!
# 488
# Failed game because of: # of tries exceeded!
# 489
# Successfully finished game, the word was: unrein!
# 490
# Failed game because of: # of tries exceeded!
# 491
# Failed game because of: # of tries exceeded!
# 492
# Failed game because of: # of tries exceeded!
# 493
# Failed game because of: # of tries exceeded!
# 494
# Failed game because of: # of tries exceeded!
# 495
# Failed game because of: # of tries exceeded!
# 496
# Failed game because of: # of tries exceeded!
# 497
# Failed game because of: # of tries exceeded!
# 498
# Failed game because of: # of tries exceeded!
# 499
# Failed game because of: # of tries exceeded!
# 500

# %%
num_success / i
# Out:
# 0.268
